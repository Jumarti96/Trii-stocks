# %% [markdown]
# ### **Load libraries**

# %%
sys.path.append('../src')
import pandas as pd
import numpy as np
import ipywidgets as widgets
from IPython.display import display
import datetime
import matplotlib.pyplot as plt
import seaborn as sns
import yfinance as yf
import risk_kit as rk
import importlib

# %%
# %load_ext autoreload
# %autoreload 2

# %%
pd.options.display.max_rows = 100
pd.options.display.max_columns = 100

# %% [markdown]
# ### **Define ticker names**

# %%
col_stock_list_path = 'colombia_stocks_trii.csv'
global_stock_list_path = 'global_stocks_trii.csv'

ticker_list_col = list(pd.read_csv(col_stock_list_path, header=None)[0])
ticker_list_glob = list(pd.read_csv(global_stock_list_path, header=None)[0])

# %%
""" Alt method
col_stock_list_path = 'colombia_stocks_trii.csv'
global_stock_list_path = 'global_stocks_trii.csv'

with open(col_stock_list_path) as s:
    ticker_list_col = []
    [ticker_list_col.append(l.replace('\n', '')) for l in s]
    s.close()
with open(global_stock_list_path) as s:
    ticker_list_global = []
    [ticker_list_global.append(l.replace('\n', '')) for l in s]
    s.close()
"""
# Out:
# " Alt method\ncol_stock_list_path = 'colombia_stocks_trii.csv'\nglobal_stock_list_path = 'global_stocks_trii.csv'\n\nwith open(col_stock_list_path) as s:\n    ticker_list_col = []\n    [ticker_list_col.append(l.replace('\n', '')) for l in s]\n    s.close()\nwith open(global_stock_list_path) as s:\n    ticker_list_global = []\n    [ticker_list_global.append(l.replace('\n', '')) for l in s]\n    s.close()\n"

# %%
# Define the number of periods per year for all calculations
# 252 is an approximation for daily
# 54 for weekly
# 12 for monthly
periods_per_year = 54

# %% [markdown]
# ### **Extract data from YFinance**

# %%
days_of_data = 365*10
end_date = datetime.date.today()
start_date = end_date - datetime.timedelta(days=days_of_data)

# %%
#interval = '1d'   # Uncomment for daily data
interval = '1wk'  # Uncomment for weekly data
# interval = '1mo' # Uncomment for monthly data

col_stocks_raw = yf.download(ticker_list_col, interval=interval, start=start_date, end=end_date, auto_adjust=True)['Close']
global_stocks_raw = yf.download(ticker_list_glob, interval=interval, start=start_date, end=end_date, auto_adjust=True)['Close']
# Out:
# [*********************100%***********************]  37 of 37 completed
#
# 1 Failed download:
# ['LTMCO.CL']: YFPricesMissingError('possibly delisted; no price data found  (1wk 2015-07-14 -> 2025-07-11)')
# [**********************57%**                     ]  28 of 49 completedHTTP Error 404:
# HTTP Error 401:
# [*********************100%***********************]  49 of 49 completed
#
# 7 Failed downloads:
# ['CFMITNIPCO', 'LTMCO', 'IBO1']: YFTzMissingError('possibly delisted; no timezone found')
# ['SQMBCO.CL', 'ENELAMCO.CL', 'IWVLM.XD', 'ICHNA.XD']: YFPricesMissingError('possibly delisted; no price data found  (1wk 2015-07-14 -> 2025-07-11)')

# %% [markdown]
# ### **Preprocessing**

# %%
# Assign a frequency to the index of the dataframes
# col_stocks_raw.index = col_stocks_raw.index.to_period(freq='D') # Uncomment to set frequency as Daily
# global_stocks_raw.index = global_stocks_raw.index.to_period(freq='D') # Uncomment to set ferquency as Daily

col_stocks_raw.index = col_stocks_raw.index.to_period(freq='W') # Uncomment to set frequency as Weekly
global_stocks_raw.index = global_stocks_raw.index.to_period(freq='W') # Uncomment to set ferquency as Weekly

# col_stocks_raw.index = col_stocks_raw.index.to_period(freq='M') # Uncomment to set frequency as Monthly
# global_stocks_raw.index = global_stocks_raw.index.to_period(freq='M') # Uncomment to set frequency as Monthly

# %%
# Merge Col and Global stock prices and returns data
stocks = pd.concat([col_stocks_raw, global_stocks_raw], axis='columns').sort_index()

# %%
stocks_not_missing = stocks.columns[stocks.isna().sum() < stocks.shape[0]*.15]

# %%
# For days without stock price info, assume the stock price is the same of the previous day
stocks = stocks[stocks_not_missing].fillna(method='bfill')

# Convert from stock prices into returns
rets = stocks.pct_change().iloc[1:]
# Out:
# C:\Users\jumar\AppData\Local\Temp\ipykernel_28744\3483962844.py:2: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   stocks = stocks[stocks_not_missing].fillna(method='bfill')

# %%
# Define start and end dates of the analysis
days_of_analysis = 365*10   # 5 years
end_date = str(datetime.date.today())
start_date = str(datetime.date.today() - datetime.timedelta(days=days_of_analysis))

# %%
rets = rets.loc[start_date:end_date]
stocks = stocks.loc[start_date:end_date]

# %%
(rets.shape, stocks.shape)
# Out:
# ((521, 54), (522, 54))

# %% [markdown]
# ### **Initial examination**

# %%
df1_to_plot = rets
df2_to_plot = stocks

fig, axes = plt.subplots(2, 1, figsize=(12, 10))
df1_to_plot.plot(ax = axes[0], legend=False)
df2_to_plot.plot(ax=axes[1], legend=False)
plt.tight_layout()

# %%
summary_stats = rk.summary_stats(rets, riskfree_rate=0, periods_per_year=periods_per_year)
summary_stats
# Out:
#                Annualized Return  Annualized Volatility   Skewness  \
# Ticker
# BCOLOMBIA.CL            0.138068               0.362471   0.373151
# BOGOTA.CL              -0.001476               0.277299  -0.790863
# BVC.CL                  0.104468               0.253333   0.687791
# CELSIA.CL               0.097029               0.288945   2.121839
# CEMARGOS.CL             0.052794               0.387385   2.723301
# CNEC.CL                -0.136546               0.350520   0.490145
# CONCONCRET.CL          -0.086547               1.087633  15.779402
# CORFICOLCF.CL          -0.012999               0.290967   0.066530
# ECOPETROL.CL            0.052532               0.385211  -0.299150
# ENKA.CL                 0.055652               0.396137   1.947305
# ETB.CL                 -0.203629               0.350725   0.644660
# EXITO.CL               -0.046826               0.356755   0.962583
# GEB.CL                  0.128679               0.238094   0.403909
# GRUBOLIVAR.CL           0.049562               0.287397   1.198706
# GRUPOARGOS.CL           0.068154               0.443572   4.961020
# GRUPOAVAL.CL           -0.024961               0.282121   0.694163
# GRUPOSURA.CL            0.068483               0.407203   1.148341
# HCOLSEL.CL              0.063976               0.214328  -0.875996
# ICOLCAP.CL              0.064289               0.211058  -0.592779
# ISA.CL                  0.146816               0.302377   0.508995
# MINEROS.CL              0.215439               0.357603   1.540332
# NUTRESA.CL              0.232253               0.462397   5.176223
# PFAVAL.CL              -0.025439               0.276920  -1.041957
# PFBCOLOM.CL             0.119371               0.312088  -0.078863
# PFCORFICOL.CL           0.003992               0.293649   0.267308
# PFDAVVNDA.CL            0.006269               0.301324   0.459833
# PFGRUPOARG.CL           0.045706               0.339468   0.733965
# PFGRUPSURA.CL           0.046546               0.382353   0.566308
# PROMIGAS.CL             0.064374               0.296015   1.885090
# TERPEL.CL               0.048518               0.282054   0.537416
# AAPL                    0.229091               0.284078  -0.229463
# AMZN                    0.258661               0.306474  -0.117233
# BAC                     0.128698               0.321809   0.007080
# BRK-B                   0.132582               0.196067  -0.213724
# C                       0.072413               0.344220  -0.025773
# CBU7.L                  0.015264               0.040694   0.220573
# CENCOSUD.SN             0.114171               0.312408  -0.215729
# CHILE.SN                0.138277               0.243057   1.035808
# CSPX.L                  0.135986               0.166267  -0.704330
# EIMI.L                  0.055456               0.190610  -0.314191
# F                       0.035247               0.385102   0.343597
# FALABELLA.SN            0.019838               0.315372   0.273053
# GE                      0.086023               0.363506  -0.074703
# GOOGL                   0.184155               0.275954   0.097143
# JETS                    0.013667               0.355019   0.162338
# JNJ                     0.078925               0.176635  -0.231437
# JPM                     0.192590               0.278493   0.080824
# META                    0.235605               0.362772   0.041615
# NKE                     0.042436               0.313718   0.297925
# NVDA                    0.828497               0.475403   0.328529
# PBR                     0.183174               0.540198   0.687564
# PFE                     0.016439               0.236367   0.047199
# SGLD.L                  0.115656               0.145142   0.097238
# VOO                     0.139239               0.177280  -0.594732
#
#                  Kurtosis  Cornish-Fisher VaR (5%)  Historic CVaR (5%)  \
# Ticker
# BCOLOMBIA.CL    14.829191                 0.060381            0.096261
# BOGOTA.CL       13.181642                 0.061650            0.096779
# BVC.CL           7.163756                 0.044335            0.069545
# CELSIA.CL       21.857910                 0.020216            0.078573
# CEMARGOS.CL     42.936748                -0.006200            0.101128
# CNEC.CL          7.186705                 0.069153            0.099722
# CONCONCRET.CL  323.852722                -2.075313            0.140517
# CORFICOLCF.CL    8.049376                 0.059798            0.092212
# ECOPETROL.CL     9.269693                 0.081608            0.114029
# ENKA.CL         14.338255                 0.040279            0.099571
# ETB.CL           9.394029                 0.066306            0.116314
# EXITO.CL        11.370530                 0.057258            0.110693
# GEB.CL           7.956059                 0.043469            0.069989
# GRUBOLIVAR.CL   13.869889                 0.039726            0.087224
# GRUPOARGOS.CL   79.263394                -0.109484            0.112762
# GRUPOAVAL.CL     9.825044                 0.049678            0.086756
# GRUPOSURA.CL    16.417471                 0.053953            0.112490
# HCOLSEL.CL      23.229189                 0.041324            0.065809
# ICOLCAP.CL      21.543145                 0.039570            0.061689
# ISA.CL           6.892609                 0.054920            0.087238
# MINEROS.CL      20.443616                 0.034675            0.090898
# NUTRESA.CL      55.544084                -0.093040            0.099861
# PFAVAL.CL       16.230230                 0.062056            0.093345
# PFBCOLOM.CL      9.614703                 0.062135            0.089020
# PFCORFICOL.CL    8.885883                 0.057022            0.090986
# PFDAVVNDA.CL    10.307544                 0.054926            0.089226
# PFGRUPOARG.CL   16.531820                 0.051379            0.098837
# PFGRUPSURA.CL   19.845867                 0.057003            0.107082
# PROMIGAS.CL     26.607005                 0.020855            0.086914
# TERPEL.CL        8.059089                 0.051536            0.087094
# AAPL             4.797424                 0.060090            0.084055
# AMZN             4.388571                 0.063670            0.089629
# BAC              6.073441                 0.066023            0.096678
# BRK-B            5.450688                 0.041500            0.058454
# C                7.989154                 0.070275            0.105586
# CBU7.L           5.986935                 0.008127            0.012287
# CENCOSUD.SN      9.029782                 0.064407            0.091195
# CHILE.SN         9.768821                 0.036545            0.064921
# CSPX.L           9.671943                 0.035867            0.052143
# EIMI.L           5.136316                 0.042477            0.058630
# F                7.474446                 0.074225            0.113296
# FALABELLA.SN    10.168386                 0.059707            0.091600
# GE               5.035056                 0.077620            0.113837
# GOOGL            3.849651                 0.056244            0.075175
# JETS            13.521441                 0.065526            0.106606
# JNJ              4.849095                 0.038500            0.051870
# JPM              7.925047                 0.053710            0.082576
# META             6.849397                 0.071635            0.104424
# NKE              7.613382                 0.060882            0.088847
# NVDA             4.347724                 0.085190            0.117457
# PBR             10.522761                 0.088956            0.146191
# PFE              4.358307                 0.050774            0.069443
# SGLD.L           5.007690                 0.028915            0.040765
# VOO              8.576003                 0.038175            0.056883
#
#                Sharpe Ratio  Max Drawdown
# Ticker
# BCOLOMBIA.CL       0.380909     -0.581655
# BOGOTA.CL         -0.005323     -0.633000
# BVC.CL             0.412373     -0.356135
# CELSIA.CL          0.335803     -0.510088
# CEMARGOS.CL        0.136284     -0.782714
# CNEC.CL           -0.389553     -0.891219
# CONCONCRET.CL     -0.079574     -0.864859
# CORFICOLCF.CL     -0.044676     -0.600359
# ECOPETROL.CL       0.136373     -0.636029
# ENKA.CL            0.140488     -0.562287
# ETB.CL            -0.580593     -0.928790
# EXITO.CL          -0.131256     -0.659980
# GEB.CL             0.540452     -0.493278
# GRUBOLIVAR.CL      0.172453     -0.534127
# GRUPOARGOS.CL      0.153648     -0.645726
# GRUPOAVAL.CL      -0.088475     -0.631598
# GRUPOSURA.CL       0.168179     -0.601465
# HCOLSEL.CL         0.298496     -0.457327
# ICOLCAP.CL         0.304602     -0.440915
# ISA.CL             0.485540     -0.451207
# MINEROS.CL         0.602452     -0.623691
# NUTRESA.CL         0.502282     -0.388657
# PFAVAL.CL         -0.091865     -0.638174
# PFBCOLOM.CL        0.382491     -0.537712
# PFCORFICOL.CL      0.013596     -0.584283
# PFDAVVNDA.CL       0.020803     -0.620423
# PFGRUPOARG.CL      0.134639     -0.698413
# PFGRUPSURA.CL      0.121735     -0.724183
# PROMIGAS.CL        0.217468     -0.485440
# TERPEL.CL          0.172018     -0.480604
# AAPL               0.806436     -0.346407
# AMZN               0.843991     -0.548307
# BAC                0.399921     -0.464260
# BRK-B              0.676210     -0.264770
# C                  0.210369     -0.534781
# CBU7.L             0.375092     -0.140871
# CENCOSUD.SN        0.365456     -0.699967
# CHILE.SN           0.568906     -0.396780
# CSPX.L             0.817878     -0.295079
# EIMI.L             0.290939     -0.367735
# F                  0.091526     -0.641058
# FALABELLA.SN       0.062904     -0.754427
# GE                 0.236648     -0.811628
# GOOGL              0.667339     -0.418639
# JETS               0.038497     -0.647329
# JNJ                0.446829     -0.205645
# JPM                0.691542     -0.396032
# META               0.649456     -0.760252
# NKE                0.135268     -0.678727
# NVDA               1.742727     -0.659360
# PBR                0.339087     -0.710030
# PFE                0.069547     -0.571144
# SGLD.L             0.796853     -0.194443
# VOO                0.785415     -0.317618

# %% [markdown]
# ### **Technical Indicators for selected stock**

# %%
# Determine a number of periods for the calculation of the moving averages
# MA_terms = 5*4 # Uncomment for daily
MA_terms = 10 # Uncomment for weekly

# %%
stock = 'PFGRUPSURA.CL' #'BCOLOMBIA.CL'  #'NVDA'
rk.technical_indicators(stocks[stock], time_window=MA_terms, return_df=True, indicators=['SMA', 'EMA', 'MACD'], macd_params=[8, 17, 9])
# rk.technical_indicators(stocks[stock], time_window=MA_terms, return_df=True, indicators=['SMA', 'EMA', 'MACD'], macd_params=[12, 26, 9])
# Out:
#                        PFGRUPSURA.CL         SMA10         EMA10  \
# Date
# 2015-07-13/2015-07-19   25543.277344           NaN  25543.277344
# 2015-07-20/2015-07-26   25193.376953           NaN  25479.659091
# 2015-07-27/2015-08-02   25403.318359           NaN  25465.778958
# 2015-08-03/2015-08-09   25053.406250           NaN  25390.802102
# 2015-08-10/2015-08-16   25039.414062           NaN  25326.913367
# ...                              ...           ...           ...
# 2025-06-09/2025-06-15   37697.753906  37609.810937  37171.902654
# 2025-06-16/2025-06-22   37737.371094  37601.124219  37274.715098
# 2025-06-23/2025-06-29   37242.132812  37509.562109  37268.791046
# 2025-06-30/2025-07-06   38371.281250  37592.762500  37469.243810
# 2025-07-07/2025-07-13   39619.289062  37820.573438  37860.161129
#
#                        SMA10 Signal  EMA10 Signal  MACD Signal
# Date
# 2015-07-13/2015-07-19         False         False        False
# 2015-07-20/2015-07-26         False         False        False
# 2015-07-27/2015-08-02         False         False        False
# 2015-08-03/2015-08-09         False         False        False
# 2015-08-10/2015-08-16         False         False        False
# ...                             ...           ...          ...
# 2025-06-09/2025-06-15          True          True        False
# 2025-06-16/2025-06-22          True          True        False
# 2025-06-23/2025-06-29         False         False        False
# 2025-06-30/2025-07-06          True          True        False
# 2025-07-07/2025-07-13          True          True        False
#
# [522 rows x 6 columns]

# %% [markdown]
# ### **Signals across all stocks**

# %%
signals = []
for stock in stocks.columns:
    stock_signals = rk.technical_indicators(stocks[stock], indicators=['SMA', 'EMA', 'MACD'], time_window=MA_terms, macd_params=[12, 26, 9], return_df=True, plot=False, signal_tolerance=.975).iloc[-1]
    stock_signals = pd.DataFrame(stock_signals).T
    stock_signals.index = [stock]
    stock_signals.rename(columns={stock: 'Price'}, inplace=True)
    signals.append(stock_signals)

signals = pd.concat(signals, axis=0)

# %%
signals
# Out:
#                       Price         SMA10          EMA10 SMA10 Signal  \
# BCOLOMBIA.CL        51440.0       51170.0    50726.20732         True
# BOGOTA.CL           31700.0  32224.064648   31824.547852         True
# BVC.CL              11900.0       12166.0   12074.988712         True
# CELSIA.CL            4520.0        4410.5    4384.532037         True
# CEMARGOS.CL         10680.0  10494.993359   10464.247876         True
# CNEC.CL              7070.0        8165.0     8208.92592        False
# CONCONCRET.CL         458.0         479.2     476.688226        False
# CORFICOLCF.CL       17580.0       17902.0   17670.575393         True
# ECOPETROL.CL         1810.0        1834.5    1838.600995         True
# ENKA.CL           18.299999         18.28       18.24907         True
# ETB.CL                 55.0          54.8      54.833354         True
# EXITO.CL             3120.0   2581.531323    2622.766813         True
# GEB.CL               3015.0        2963.0    2961.848652         True
# GRUBOLIVAR.CL  70030.367188  70467.516406   70327.550893         True
# GRUPOARGOS.CL  23824.189453  22013.552148   22188.392965         True
# GRUPOAVAL.CL          575.0    590.384589     581.867391        False
# GRUPOSURA.CL    55449.90625  46920.984766   47743.436629         True
# HCOLSEL.CL          18588.0      18303.65   18226.659164         True
# ICOLCAP.CL          16665.0   16420.91416   16354.408674         True
# ISA.CL              19420.0  19764.448242   19583.763376         True
# MINEROS.CL           7050.0        7179.0    6968.264281         True
# NUTRESA.CL         129960.0      127172.0  126870.301671         True
# PFAVAL.CL             570.0    578.872937     571.813568         True
# PFBCOLOM.CL         45060.0       43348.0   43423.620387         True
# PFCORFICOL.CL       15820.0  16015.557617   15912.440985         True
# PFDAVVNDA.CL        22200.0       22856.0   22399.093652        False
# PFGRUPOARG.CL  17307.208984  16542.840332   16585.643064         True
# PFGRUPSURA.CL  39619.289062  37820.573438   37860.161129         True
# PROMIGAS.CL          6730.0        6813.0    6810.290211         True
# TERPEL.CL           12280.0       12178.0   12098.712744         True
# AAPL             212.410004    203.378334     206.154266         True
# AMZN             222.259995    210.898001     212.472171         True
# BAC               46.970001     45.010829      45.200969         True
# BRK-B            478.269989    495.033997     492.515849        False
# C                 87.080002     78.826317      79.961198         True
# CBU7.L           139.139999    138.366002     138.499507         True
# CENCOSUD.SN     3135.600098   3196.910034    3133.294776         True
# CHILE.SN         139.479996    141.942999     139.376731         True
# CSPX.L           669.599976    639.148999     641.660449         True
# EIMI.L            39.540001        37.953      38.033487         True
# F                     11.91     10.746468      10.847183         True
# FALABELLA.SN         4893.0    4812.33999    4740.140867         True
# GE               252.201706    240.748422     238.122398         True
# GOOGL            177.619995    170.860179     172.477421         True
# JETS              25.610001        22.832      23.008335         True
# JNJ              157.690002    153.651352     154.564893         True
# JPM              288.190002    271.065942      272.86191         True
# META              727.23999    674.667621     680.106596         True
# NKE               74.620003     64.617765      67.035677         True
# NVDA             164.100006    142.714431     144.999063         True
# PBR                   12.83     12.094445      12.353176         True
# PFE               25.780001     23.871292      24.335261         True
# SGLD.L           319.730011    319.978003     317.713715         True
# VOO              575.289978    548.851105     551.087187         True
#
#               EMA10 Signal MACD Signal
# BCOLOMBIA.CL          True       False
# BOGOTA.CL             True       False
# BVC.CL                True       False
# CELSIA.CL             True        True
# CEMARGOS.CL           True       False
# CNEC.CL              False       False
# CONCONCRET.CL        False       False
# CORFICOLCF.CL         True       False
# ECOPETROL.CL          True        True
# ENKA.CL               True        True
# ETB.CL                True        True
# EXITO.CL              True        True
# GEB.CL                True       False
# GRUBOLIVAR.CL         True       False
# GRUPOARGOS.CL         True        True
# GRUPOAVAL.CL          True       False
# GRUPOSURA.CL          True        True
# HCOLSEL.CL            True       False
# ICOLCAP.CL            True       False
# ISA.CL                True       False
# MINEROS.CL            True        True
# NUTRESA.CL            True       False
# PFAVAL.CL             True       False
# PFBCOLOM.CL           True       False
# PFCORFICOL.CL         True       False
# PFDAVVNDA.CL          True       False
# PFGRUPOARG.CL         True       False
# PFGRUPSURA.CL         True       False
# PROMIGAS.CL           True        True
# TERPEL.CL             True        True
# AAPL                  True        True
# AMZN                  True        True
# BAC                   True        True
# BRK-B                False       False
# C                     True        True
# CBU7.L                True        True
# CENCOSUD.SN           True       False
# CHILE.SN              True       False
# CSPX.L                True        True
# EIMI.L                True        True
# F                     True        True
# FALABELLA.SN          True        True
# GE                    True        True
# GOOGL                 True        True
# JETS                  True        True
# JNJ                   True        True
# JPM                   True        True
# META                  True        True
# NKE                   True        True
# NVDA                  True        True
# PBR                   True        True
# PFE                   True        True
# SGLD.L                True       False
# VOO                   True        True

# %% [markdown]
# ### **Stock filtering by signal**

# %%
signals_filtered = signals[np.int64(signals['MACD Signal']) + np.int64(signals[f'SMA{MA_terms} Signal']) + np.int64(signals[f'EMA{MA_terms} Signal']) >= 2]

# %%
selected_stocks_rets = rets[signals_filtered.index]
selected_stocks_stocks = stocks[signals_filtered.index]

# %%
selected_stocks_rets.index = selected_stocks_rets.index.astype('str').str.split('/').str[1]
selected_stocks_stocks.index = selected_stocks_stocks.index.astype('str').str.split('/').str[1]

rets.index = rets.index.astype('str').str.split('/').str[1]
stocks.index = stocks.index.astype('str').str.split('/').str[1]

# %% [markdown]
# ### **Export datasets and an index for the Sharpe-Ratio maximizing allocation**

# %%
# Selected stocks dataset
selected_stocks_rets.to_csv('selected_stocks_rets.csv')
selected_stocks_stocks.to_csv('selected_stocks_stocks.csv')

# Concatenated returns and stock prices datasets
rets.to_csv('all_rets.csv')
stocks.to_csv('all_stocks.csv')
